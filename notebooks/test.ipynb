# %%
print("hello")
# Out:
# hello

# %%
import sys
import os
#!{sys.executable} -m pip install --upgrade pip
# !{sys.executable} -m pip install xgboost
# Out:
# ...
#    ---------------------------------------- 0.0/150.0 MB ? eta -:--:--
#    ---------------------------------------- 0.3/150.0 MB ? eta -:--:--
#    ---------------------------------------- 0.5/150.0 MB 1.6 MB/s eta 0:01:34
#    ---------------------------------------- 0.8/150.0 MB 1.2 MB/s eta 0:02:03
#    ---------------------------------------- 1.0/150.0 MB 1.6 MB/s eta 0:01:36
#    ---------------------------------------- 1.3/150.0 MB 1.6 MB/s eta 0:01:36
#    ---------------------------------------- 1.8/150.0 MB 1.5 MB/s eta 0:01:36
#     --------------------------------------- 2.1/150.0 MB 1.5 MB/s eta 0:01:36
#     --------------------------------------- 2.4/150.0 MB 1.5 MB/s eta 0:01:36
#     --------------------------------------- 2.6/150.0 MB 1.5 MB/s eta 0:01:36
#     --------------------------------------- 2.9/150.0 MB 1.5 MB/s eta 0:01:36
#     --------------------------------------- 3.4/150.0 MB 1.5 MB/s eta 0:01:35
# ...
